# %%
import pandas as pd

df = pd.read_parquet('output/Rawdata_2025_before_reload.parquet.gzip')

# %%
df
# Out:
#      Название компании (заполняется автоматически)  \
# 0                                     3Logic_Group
# 1                                     3Logic_Group
# 2                                     3Logic_Group
# 3                                     3Logic_Group
# 4                                     3Logic_Group
# ...                                            ...
# 2012                                          Teva
# 2013                                          Teva
# 2014                                          Teva
# 2015                                    12_STOREEZ
# 2016                                    12_STOREEZ
#
#            Подразделение 1 уровня  \
# 0          Новый Ай Ти Проект ООО
# 1          Новый Ай Ти Проект ООО
# 2          Новый Ай Ти Проект ООО
# 3          Новый Ай Ти Проект ООО
# 4          Новый Ай Ти Проект ООО
# ...                           ...
# 2012  Отдел по работе с клиентами
# 2013  Отдел по работе с клиентами
# ...
